# %% [markdown]
# # 基础设施数据查看

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import geopandas as gpd
#       3 from shapely.geometry import Point
# ----> 4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
from_path = "E:\\Netease\\智慧城市\\4.处理数据\\rawdata\\北京基础设施POI\\"
to_path = "E:\\Netease\\智慧城市\\4.处理数据\\tempdata\\"

# %%
# 获取列表
import os
dir_lst = os.listdir(from_path)
dir_lst = [i[:-4] for i in dir_lst[1:]] # 清除ipy记录点
dir_lst
# Out:
# ['交通设施服务',
#  '住宿服务',
#  '体育休闲服务',
#  '公共设施',
#  '公司企业',
#  '医疗保健服务',
#  '商务住宅',
#  '政府机构及社会团体',
#  '生活服务',
#  '科教文化服务',
#  '购物',
#  '金融保险服务',
#  '风景名胜',
#  '餐饮']

# %%
# 批量转换
for name in dir_lst:
    # 读取csv
    df = pd.read_csv(from_path+r"{}.csv".format(name),encoding='gbk')
    # 列重命名
    df.columns = ['name','type_b','type_m','type_s','area0','area1','area2','longitude','latitude']

    # csv转shp
    geometry = [Point(xy) for xy in zip(df.longitude, df.latitude)]
    gdf = gpd.GeoDataFrame(df, geometry=geometry)

    # 导出shp
    gdf.to_file(to_path+r"{}.shp".format(name), crs="EPSG:4326")
    print(name)

# %%
name = '交通设施服务'
df = pd.read_csv(from_path+r"{}.csv".format(name),encoding='gbk')
df
# Out:
#                        名称      大类    中类      小类    省    市    区   WGS84_Lng
# 0                石洞子(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  怀柔区  116.634099  \
# 1                 帽山(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  怀柔区  116.623163
# 2                头道穴(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  怀柔区  116.614111
# 3                 胡营(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  怀柔区  116.568024
# 4                 黄营(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  怀柔区  116.584706
# ...                   ...     ...   ...     ...  ...  ...  ...         ...
# 72242       停车场(长城脚下的公社东)  交通设施服务   停车场   公共停车场  北京市  北京市  延庆区  116.045398
# 72243          长城脚下的公社停车场  交通设施服务   停车场   公共停车场  北京市  北京市  延庆区  116.049138
# 72244      石门山庄(招呼站)(公交站)  交通设施服务  公交车站  公交车站相关  北京市  北京市  延庆区  116.034643
# 72245  长城华人怀思堂停车场(炎黄纪念馆南)  交通设施服务   停车场   公共停车场  北京市  北京市  延庆区  116.034222
# 72246           石峡关长城-停车场  交通设施服务   停车场   公共停车场  北京市  北京市  延庆区  115.955940
#
#        WGS84_Lat
# 0      41.029744
# 1      41.002472
# ...
